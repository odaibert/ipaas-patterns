# %% [markdown]
# # Clean Up Resources
#
# This notebook deletes the resource group created by the Contact Form Intake lab.

# %% [markdown]
# ### Warning
#
# This action permanently deletes the entire resource group.

# %%
import sys
sys.path.insert(1, '../../shared')
import utils

# Configuration - must match the main notebook
deployment_name = "contact-form"
resource_group_name = f"rg-{deployment_name}"

# %%
# Confirm deletion
confirm = input(f"Type 'DELETE' to confirm deletion of resource group '{resource_group_name}': ")

if confirm == "DELETE":
    utils.delete_resource_group(resource_group_name, no_wait=False)
    print(f"Resource group '{resource_group_name}' has been deleted.")
else:
    print("Deletion cancelled.")
