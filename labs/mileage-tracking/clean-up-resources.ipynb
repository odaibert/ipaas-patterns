# %% [markdown]
# # 🗑️ Clean Up Resources
#
# This notebook deletes all resources created by the Mileage Tracking lab.

# %%
import sys
sys.path.insert(1, '../../shared')
import utils

# Configuration - must match the main notebook
deployment_name = "mileage-tracking"
resource_group_name = f"rg-{deployment_name}"

# %% [markdown]
# ### ⚠️ Warning
#
# Running the cell below will **permanently delete** all resources in the resource group. This action cannot be undone.

# %%
# Confirm deletion
confirm = input(f"Type 'DELETE' to confirm deletion of resource group '{resource_group_name}': ")

if confirm == "DELETE":
    utils.delete_resource_group(resource_group_name, no_wait=False)
    print(f"\n✅ Resource group '{resource_group_name}' has been deleted.")
else:
    print("\n❌ Deletion cancelled.")
